# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import re
from konlpy.tag import Okt
from tensorflow.keras.preprocessing.text import Tokenizer
import numpy as np
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %% [markdown]
# ## word2vec 임포트

# %%
from gensim.models import Word2Vec
ko_model= Word2Vec.load('word2vec_movie.model')

# %%
# 모델 확인 
ko_model['평점']
# Out:
# C:\Users\leeso\anaconda\envs\crawl\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# array([ 1.37894905e+00,  9.87708807e-01, -5.03856897e-01, -5.77842712e-01,
#         2.71781266e-01, -4.84355837e-01,  7.09133685e-01,  4.83562052e-01,
#        -2.12013578e+00, -1.53143942e+00, -2.21780896e+00, -4.36312646e-01,
#        -7.34049320e-01,  1.32041967e+00, -5.64270079e-01, -1.27724886e+00,
#        -6.67323589e-01,  1.25785872e-01,  8.86485755e-01,  5.52864611e-01,
#         1.83218852e-01,  3.81816566e-01, -1.45142281e+00,  1.32863295e+00,
#        -2.28901446e-01, -8.47232699e-01, -1.07557023e+00,  1.31017220e+00,
#        -1.11492407e+00,  4.67573434e-01, -1.73956227e+00,  5.30944943e-01,
#        -7.81446993e-01,  8.03073198e-02,  1.06718056e-02, -7.76855171e-01,
#        -5.18462360e-01,  1.82522148e-01, -3.42364371e-01,  8.30587745e-01,
#        -6.77727163e-01,  2.17546612e-01, -8.99270713e-01,  3.50216419e-01,
#         1.27970874e-01, -1.43166259e-02, -6.87184393e-01,  7.87147760e-01,
#         3.13703835e-01, -1.34181023e+00, -2.88948655e-01,  4.87908751e-01,
#        -4.40034330e-01, -1.24677551e+00,  1.91388345e+00,  6.20720275e-02,
#         2.17562735e-01,  1.57734001e+00, -9.75034893e-01, -9.16822493e-01,
#        -1.28605997e-03, -9.09354508e-01,  6.59039021e-02, -1.49107993e-01,
#         7.56315291e-01, -2.35793933e-01, -4.70089018e-02, -1.36861193e+00,
#        -1.82109869e+00, -2.76795030e-01, -1.14091682e+00,  5.86995006e-01,
#        -1.56029269e-01, -7.26923466e-01,  1.91490936e+00,  1.51382649e+00,
#         1.50504267e+00,  8.43366921e-01, -5.34677446e-01, -1.56727165e-01,
#        -1.01984635e-01,  2.61996478e-01,  6.94197237e-01, -1.58868562e-02,
#        -2.45960546e+00,  7.53313005e-01, -2.39308095e+00, -1.71987832e-01,
#        -7.16078401e-01, -2.36521065e-02,  1.96674049e-01,  2.53489375e-01,
#        -1.37074280e+00,  1.99862218e+00, -1.62576354e+00, -9.51833278e-02,
#        -2.33517003e+00, -1.19210348e-01, -5.35374522e-01,  5.34276724e-01,
#         3.40814203e-01, -9.24165905e-01,  4.04475778e-01,  1.42486405e+00,
#         6.24129474e-01,  1.50174610e-02, -5.80463648e-01, -1.29222524e+00,
#         4.28030491e-02,  7.02565312e-01,  8.17283809e-01,  8.40790153e-01,
#        -3.29402745e-01, -1.98169827e+00, -1.63232219e+00, -1.35585296e+00,
#         1.65320903e-01,  8.78293335e-01, -5.97452402e-01, -1.20649469e+00,
#         1.48789003e-01, -2.45120630e-01, -4.30667073e-01,  7.01792955e-01,
#        -6.28360271e-01, -1.01060845e-01,  9.60004985e-01,  1.21269250e+00,
#        -6.82425559e-01,  4.79231983e-01, -1.70215476e+00,  1.10598314e+00,
#         2.02842426e+00, -6.66181982e-01,  1.52281523e-01,  1.93755940e-01,
#         8.20553601e-01,  3.45031060e-02, -6.68196499e-01,  1.61060047e+00,
#         2.65534937e-01,  1.24002767e+00,  1.61996996e+00, -2.00592852e+00,
#         6.29359245e-01, -1.35131919e+00,  2.76473194e-01, -4.46986228e-01,
#        -2.53276855e-01,  1.53764343e+00,  6.05187058e-01,  6.05335459e-02,
#        -5.39341196e-02,  5.79544425e-01,  4.22562987e-01, -1.97442901e+00,
#         9.51142833e-02, -9.14012849e-01, -5.47553599e-01, -5.43647826e-01,
#         3.91458243e-01, -1.23735213e+00, -1.14660323e+00,  1.74715757e+00,
#         6.80540562e-01,  2.29177308e+00,  6.59082353e-01,  1.84193575e+00,
#        -1.89989954e-01, -9.19043645e-02,  1.62832558e+00,  8.45791772e-02,
#        -1.06711626e-01, -1.12618256e+00, -1.31909204e+00,  2.38393173e-01,
#        -5.44293463e-01,  2.38525525e-01, -2.90395641e+00, -5.06984890e-01,
#        -6.50369704e-01, -1.33505285e+00,  6.70029342e-01, -3.81612420e-01,
#        -2.00835848e+00,  1.00355136e+00, -6.54984117e-01,  1.10105038e+00,
#         1.05699301e-01,  6.22650683e-01,  4.73337799e-01, -2.59310812e-01,
#         4.99202013e-01,  7.38488376e-01, -1.88814163e+00,  7.97092259e-01,
#         1.51610231e+00,  2.06020311e-01, -1.39211369e+00, -2.56290108e-01],
#       dtype=float32)

# %%
print(ko_model.wv.most_similar("최민식"))
# Out:
# [('한석규', 0.9022693634033203), ('이민호', 0.8778703808784485), ('이미숙', 0.8716947436332703), ('설경구', 0.8695714473724365), ('김명민', 0.8679181933403015), ('이정재', 0.863978385925293), ('정재영', 0.8619986176490784), ('메릴', 0.8613458871841431), ('이주승', 0.861168622970581), ('공리', 0.8594560027122498)]

# %% [markdown]
# ## Train Test Data 불러오기

# %%
import pickle
import pandas as pd
test = pd.read_pickle("token_test_data_ver2.pkl")
train = pd.read_pickle("token_train_data_ver2.pkl")

# train, test 명시 
training_sentences = train['token']
testing_sentences = test['token']

training_labels = train['label']
testing_labels = test['label']

training_sentences.shape, testing_sentences.shape, training_labels.shape, testing_labels.shape
# Out:
# ((146182,), (49157,), (146182,), (49157,))

# %%
training_sentences
# Out:
# 0                                       [더빙, 진짜, 짜증나다, 목소리]
# 1                  [흠, 포스터, 보고, 초딩, 영화, 줄, 오버, 연기, 가볍다, 않다]
# 2                                  [무재, 밓었, 다그, 래서, 보다, 추천]
# 3                      [교도소, 이야기, 구먼, 솔직하다, 재미, 없다, 평점, 조정]
# 4         [몬페, 의, 익살스럽다, 연기, 돋보이다, 영화, 스파이더맨, 늙다, 보이다, 하...
#                                 ...
# 149995                                      [인간, 문제, 소, 죄인]
# 149996                                             [평점, 낮다]
# 149997                  [이, 뭐, 한국인, 거들다, 먹거리, 필리핀, 혼혈, 착하다]
# 149998                      [청춘, 영화, 최고봉, 방황, 우울하다, 날, 자화상]
# 149999                    [한국, 영화, 최초, 수간, 하다, 내용, 담기다, 영화]
# Name: token, Length: 146182, dtype: object

# %% [markdown]
# ## Tokenize / Padding

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# 파라미터 명시 
vocab_size = 20000
embedding_dim = 200
max_length = 30
truct_type = 'post'
padding_type = 'post'
oov_tok = '<OOV>'

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(training_sentences)
word_index = tokenizer.word_index

word_index, len(word_index)
# Out:
# ({'<OOV>': 1,
#   '영화': 2,
#   '하다': 3,
#   '보다': 4,
#   '없다': 5,
#   '있다': 6,
#   '좋다': 7,
#   '재밌다': 8,
#   '정말': 9,
#   '것': 10,
#   '되다': 11,
#   '같다': 12,
#   '진짜': 13,
#   '이다': 14,
#   '이': 15,
#   '점': 16,
#   '아니다': 17,
#   '않다': 18,
#   '만들다': 19,
#   '연기': 20,
#   '나오다': 21,
#   '평점': 22,
#   '최고': 23,
#   '왜': 24,
#   '스토리': 25,
#   '생각': 26,
#   '드라마': 27,
#   '1': 28,
#   '감동': 29,
#   '사람': 30,
#   'ㅋㅋㅋ': 31,
#   '보고': 32,
#   '이렇다': 33,
#   '말': 34,
#   '아깝다': 35,
#   '더': 36,
#   '때': 37,
#   '배우': 38,
#   'ㅋㅋ': 39,
#   '내': 40,
#   '거': 41,
#   '감독': 42,
#   '재미있다': 43,
#   '뭐': 44,
#   '내용': 45,
#   '재미': 46,
#   '그냥': 47,
#   '주다': 48,
#   '그': 49,
#   '좀': 50,
#   '자다': 51,
#   '지루하다': 52,
#   '재미없다': 53,
#   '시간': 54,
#   '쓰레기': 55,
#   '가다': 56,
#   '수': 57,
#   '모르다': 58,
#   '들다': 59,
#   '그렇다': 60,
#   '10': 61,
#   '싶다': 62,
#   '나': 63,
#   '작품': 64,
#   '알다': 65,
#   '사랑': 66,
#   '하나': 67,
#   '다시': 68,
#   '마지막': 69,
#   '볼': 70,
#   '2': 71,
#   '오다': 72,
#   'ㅋ': 73,
#   '처음': 74,
#   '완전': 75,
#   '정도': 76,
#   '많다': 77,
#   '장면': 78,
#   '액션': 79,
#   '주인공': 80,
#   '3': 81,
#   '차다': 82,
#   '안되다': 83,
#   'ㅠㅠ': 84,
#   '나다': 85,
#   '지금': 86,
#   '돈': 87,
#   '최악': 88,
#   '이야기': 89,
#   '걸': 90,
#   '임': 91,
#   '느낌': 92,
#   '넘다': 93,
#   '연출': 94,
#   '개': 95,
#   '끝': 96,
#   '듯': 97,
#   '좋아하다': 98,
#   '별로': 99,
#   '명작': 100,
#   '역시': 101,
#   '받다': 102,
#   '남다': 103,
#   '이해': 104,
#   'ㅡㅡ': 105,
#   '이영화': 106,
#   '괜찮다': 107,
#   '안': 108,
#   '버리다': 109,
#   '또': 110,
#   '느끼다': 111,
#   '여자': 112,
#   '때문': 113,
#   '먹다': 114,
#   '난': 115,
#   '아름답다': 116,
#   '해주다': 117,
#   '중': 118,
#   '꼭': 119,
#   '편': 120,
#   '보기': 121,
#   '기억': 122,
#   '결말': 123,
#   '어떻다': 124,
#   'ㅎㅎ': 125,
#   '아쉽다': 126,
#   '마음': 127,
#   '인생': 128,
#   '소재': 129,
#   'ㅠ': 130,
#   '뻔하다': 131,
#   '끄다': 132,
#   '애': 133,
#   '못': 134,
#   '보여주다': 135,
#   '수준': 136,
#   '어리다': 137,
#   '무섭다': 138,
#   '현실': 139,
#   '맞다': 140,
#   '한번': 141,
#   '가장': 142,
#   '재다': 143,
#   '웃기다': 144,
#   '반전': 145,
#   '전개': 146,
#   '매력': 147,
#   '되어다': 148,
#   '남자': 149,
#   '한국': 150,
#   '끝나다': 151,
#   '가슴': 152,
#   '낮다': 153,
#   '말다': 154,
#   '죽다': 155,
#   '저': 156,
#   '슬프다': 157,
#   '높다': 158,
#   '음악': 159,
#   '늘다': 160,
#   '유치하다': 161,
#   '아이': 162,
#   '알': 163,
#   '멋지다': 164,
#   '원작': 165,
#   '줄': 166,
#   '인간': 167,
#   '솔직하다': 168,
#   '우리': 169,
#   '무슨': 170,
#   '쓰다': 171,
#   '크다': 172,
#   '추천': 173,
#   '게': 174,
#   '눈물': 175,
#   '만': 176,
#   '살다': 177,
#   '함': 178,
#   '속': 179,
#   '내다': 180,
#   '야하다': 181,
#   '번': 182,
#   '도': 183,
#   '자체': 184,
#   '눈': 185,
#   '허다': 186,
#   '찍다': 187,
#   '짜증나다': 188,
#   '코미디': 189,
#   '캐릭터': 190,
#   '보이다': 191,
#   '뭔가': 192,
#   '움': 193,
#   '대한': 194,
#   '돼다': 195,
#   '전혀': 196,
#   '이상': 197,
#   '연기력': 198,
#   '이쁘다': 199,
#   '대박': 200,
#   '여운': 201,
#   '지다': 202,
#   '미치다': 203,
#   '기대': 204,
#   '건지다': 205,
#   '모두': 206,
#   '4': 207,
#   '개봉': 208,
#   '별': 209,
#   '공감': 210,
#   '일본': 211,
#   '중간': 212,
#   '기대하다': 213,
#   '영상': 214,
#   '아주': 215,
#   '부분': 216,
#   '시리즈': 217,
#   '모습': 218,
#   '전': 219,
#   '귀엽다': 220,
#   '계속': 221,
#   '제목': 222,
#   '시키다': 223,
#   '요': 224,
#   '가족': 225,
#   '치다': 226,
#   '5': 227,
#   '내내': 228,
#   '급': 229,
#   '뿐': 230,
#   'ㅎ': 231,
#   '믿다': 232,
#   '보지': 233,
#   'oo': 234,
#   '진심': 235,
#   '다른': 236,
#   '몰입': 237,
#   '실망': 238,
#   '후': 239,
#   '표현': 240,
#   '기분': 241,
#   '무엇': 242,
#   '0': 243,
#   '대단하다': 244,
#   '작가': 245,
#   'ㅜㅜ': 246,
#   '잔잔하다': 247,
#   '떨어지다': 248,
#   '위': 249,
#   '이제': 250,
#   '7': 251,
#   '웃다': 252,
#   '요즘': 253,
#   '공포': 254,
#   '스릴러': 255,
#   '빠지다': 256,
#   '감': 257,
#   '개인': 258,
#   '긴장감': 259,
#   '용': 260,
#   'ㅡ': 261,
#   '잼': 262,
#   '조금': 263,
#   '대사': 264,
#   '모든': 265,
#   '굿': 266,
#   '점도': 267,
#   '애니': 268,
#   '짜다': 269,
#   '이유': 270,
#   '분': 271,
#   '제대로': 272,
#   '삶': 273,
#   '알바': 274,
#   '건': 275,
#   '노래': 276,
#   '울다': 277,
#   '욕': 278,
#   '극장': 279,
#   '점수': 280,
#   '시작': 281,
#   '막장': 282,
#   '나름': 283,
#   '이상하다': 284,
#   '기': 285,
#   '예쁘다': 286,
#   '깊다': 287,
#   '제일': 288,
#   '차라리': 289,
#   '놈': 290,
#   '짱': 291,
#   '8': 292,
#   '친구': 293,
#   '느껴지다': 294,
#   '제': 295,
#   '해보다': 296,
#   '당시': 297,
#   '영화로': 298,
#   '노잼': 299,
#   '어설프다': 300,
#   '류': 301,
#   '절대': 302,
#   '의미': 303,
#   '빼다': 304,
#   '잇다': 305,
#   '세상': 306,
#   '위해': 307,
#   '따뜻하다': 308,
#   '미국': 309,
#   '찾다': 310,
#   '훌륭하다': 311,
#   '도대체': 312,
#   '공포영화': 313,
#   '앞': 314,
#   '웃음': 315,
#   '생각나다': 316,
#   '설정': 317,
#   '로': 318,
#   '그리다': 319,
#   '대다': 320,
#   '죽이다': 321,
#   '힘들다': 322,
#   '의': 323,
#   '물': 324,
#   '수작': 325,
#   '일': 326,
#   '다르다': 327,
#   '써다': 328,
#   '9': 329,
#   '우리나라': 330,
#   '뭘': 331,
#   '초반': 332,
#   '싫다': 333,
#   '남': 334,
#   '출연': 335,
#   '명': 336,
#   '사실': 337,
#   '답답하다': 338,
#   'b': 339,
#   'cg': 340,
#   '따다': 341,
#   '추억': 342,
#   '해': 343,
#   '장난': 344,
#   '한국영': 345,
#   '멋있다': 346,
#   '가지': 347,
#   '놓다': 348,
#   '시나리오': 349,
#   '소리': 350,
#   '신선하다': 351,
#   'ooo': 352,
#   '분위기': 353,
#   '아프다': 354,
#   '필요없다': 355,
#   '관객': 356,
#   '시대': 357,
#   '팬': 358,
#   '지루함': 359,
#   '어이없다': 360,
#   '살': 361,
#   '자신': 362,
#   '잊다': 363,
#   '나쁘다': 364,
#   '감정': 365,
#   '봄': 366,
#   '졸작': 367,
#   '기다': 368,
#   '오늘': 369,
#   '영화관': 370,
#   '안타깝다': 371,
#   '엄마': 372,
#   '접': 373,
#   '엔딩': 374,
#   '정신': 375,
#   '스럽다': 376,
#   '제발': 377,
#   '인상': 378,
#   '부족하다': 379,
#   '배우다': 380,
#   '더럽다': 381,
#   '포스터': 382,
#   '더빙': 383,
#   '캐스팅': 384,
#   '문제': 385,
#   '최고다': 386,
#   '준': 387,
#   '평가': 388,
#   '코믹': 389,
#   '라면': 390,
#   '얼마나': 391,
#   '6': 392,
#   'tv': 393,
#   '애니메이션': 394,
#   '어색하다': 395,
#   '서다': 396,
#   'ㅠㅠㅠ': 397,
#   '몰입도': 398,
#   '음': 399,
#   '낫다': 400,
#   '티비': 401,
#   '배경': 402,
#   '강추': 403,
#   '대해': 404,
#   '쓸다': 405,
#   '망하다': 406,
#   '살리다': 407,
#   '두다': 408,
#   '적다': 409,
#   '유쾌하다': 410,
#   '뒤': 411,
#   '비다': 412,
#   '킬링타임': 413,
#   '맘': 414,
#   '스릴': 415,
#   '만화': 416,
#   '충격': 417,
#   '개연': 418,
#   '얘기': 419,
#   '질': 420,
#   '를': 421,
#   '나가다': 422,
#   '완벽하다': 423,
#   '전쟁': 424,
#   '진부하다': 425,
#   '책': 426,
#   '즐겁다': 427,
#   '구성': 428,
#   '머리': 429,
#   '데': 430,
#   'ㅜ': 431,
#   '예술': 432,
#   '갈수록': 433,
#   '어디': 434,
#   '놀라다': 435,
#   '얼굴': 436,
#   '매우': 437,
#   '후회': 438,
#   '웃기': 439,
#   '이름': 440,
#   '기도': 441,
#   '머': 442,
#   '읽다': 443,
#   '어울리다': 444,
#   '옛날': 445,
#   '적': 446,
#   '들이다': 447,
#   '영화인': 448,
#   '장르': 449,
#   '행복하다': 450,
#   '집중': 451,
#   '꽤': 452,
#   '이후': 453,
#   '집': 454,
#   '은': 455,
#   'ost': 456,
#   '주연': 457,
#   '존나': 458,
#   '새롭다': 459,
#   '억지': 460,
#   '멀다': 461,
#   '건가': 462,
#   '누구': 463,
#   '다큐': 464,
#   '상황': 465,
#   '날': 466,
#   '진': 467,
#   '언제': 468,
#   '비': 469,
#   '그것': 470,
#   '글': 471,
#   '짜증': 472,
#   'ㅎㅎㅎ': 473,
#   '시즌': 474,
#   '씬': 475,
#   '충분하다': 476,
#   '생기다': 477,
#   '예전': 478,
#   '후반': 479,
#   '역사': 480,
#   '다운': 481,
#   '밉다': 482,
#   '누가': 483,
#   '여기': 484,
#   '불쌍하다': 485,
#   '걸작': 486,
#   '궁금하다': 487,
#   '두': 488,
#   '약간': 489,
#   '자기': 490,
#   '실화': 491,
#   '니': 492,
#   '소름': 493,
#   '인물': 494,
#   '해도': 495,
#   '발연기': 496,
#   '심하다': 497,
#   '그대로': 498,
#   '등': 499,
#   '잔인하다': 500,
#   '방송': 501,
#   '시절': 502,
#   '작': 503,
#   '부': 504,
#   '비디오': 505,
#   '순수하다': 506,
#   '비슷하다': 507,
#   '대체': 508,
#   '아들': 509,
#   '한마디': 510,
#   '다음': 511,
#   '소설': 512,
#   '사회': 513,
#   '드리다': 514,
#   '간만': 515,
#   '로맨스': 516,
#   '어렵다': 517,
#   '판': 518,
#   '보': 519,
#   '비교': 520,
#   '필요하다': 521,
#   '초딩': 522,
#   '쉬다': 523,
#   '만점': 524,
#   '감성': 525,
#   '네이버': 526,
#   '자': 527,
#   '남기다': 528,
#   '따르다': 529,
#   '여배우': 530,
#   '타다': 531,
#   '전체': 532,
#   '만나다': 533,
#   '떠나다': 534,
#   '여주': 535,
#   '상당하다': 536,
#   '꿈': 537,
#   '사랑스럽다': 538,
#   '코': 539,
#   '이르다': 540,
#   '나이': 541,
#   '당하다': 542,
#   '성룡': 543,
#   '편이': 544,
#   '굉장하다': 545,
#   '너': 546,
#   '혼자': 547,
#   '터지다': 548,
#   '순간': 549,
#   '년': 550,
#   '교훈': 551,
#   '삼류': 552,
#   '돌리다': 553,
#   '감사하다': 554,
#   '존재': 555,
#   '힘': 556,
#   'ㅉㅉ': 557,
#   '풀다': 558,
#   '진정하다': 559,
#   '주제': 560,
#   '바로': 561,
#   '바라다': 562,
#   '목소리': 563,
#   '잡다': 564,
#   '망치다': 565,
#   '돋다': 566,
#   '화려하다': 567,
#   '안보': 568,
#   '거의': 569,
#   '죽': 570,
#   '당신': 571,
#   '몇번': 572,
#   '낭비': 573,
#   '가볍다': 574,
#   '나라': 575,
#   '질질': 576,
#   '엄청나다': 577,
#   '줄거리': 578,
#   '독특하다': 579,
#   '맞추다': 580,
#   '지나다': 581,
#   '딸': 582,
#   'sf': 583,
#   '신': 584,
#   '성하다': 585,
#   '판타지': 586,
#   '점주': 587,
#   '아버지': 588,
#   '좀비': 589,
#   '담다': 590,
#   '피': 591,
#   '이번': 592,
#   '갑자기': 593,
#   '의도': 594,
#   '넣다': 595,
#   '전부': 596,
#   '뜨다': 597,
#   '어른': 598,
#   '상영': 599,
#   '실제': 600,
#   '재': 601,
#   '각본': 602,
#   '시청률': 603,
#   '흥미롭다': 604,
#   '제작': 605,
#   '넘치다': 606,
#   '맛': 607,
#   '평론가': 608,
#   '곳': 609,
#   '바': 610,
#   '만하': 611,
#   '한편': 612,
#   '땜': 613,
#   '화면': 614,
#   '영': 615,
#   '답': 616,
#   '필요': 617,
#   '그녀': 618,
#   '기다리다': 619,
#   '극장판': 620,
#   '막': 621,
#   '10년': 622,
#   '간다': 623,
#   '중국': 624,
#   '만들어지다': 625,
#   '란': 626,
#   '볼때': 627,
#   '세계': 628,
#   '이기다': 629,
#   '억지스럽다': 630,
#   '이하': 631,
#   '밑': 632,
#   '바꾸다': 633,
#   '세': 634,
#   '발': 635,
#   '굳다': 636,
#   '관람': 637,
#   '평': 638,
#   '선': 639,
#   '오글거리다': 640,
#   '스타일': 641,
#   '선택': 642,
#   '똥': 643,
#   '복수': 644,
#   '성우': 645,
#   '뻔': 646,
#   '일단': 647,
#   '가치': 648,
#   '요소': 649,
#   '항상': 650,
#   '둘': 651,
#   '흥행': 652,
#   '역': 653,
#   '달다': 654,
#   '힘드다': 655,
#   '너무하다': 656,
#   '올리다': 657,
#   '부르다': 658,
#   '보내다': 659,
#   '그때': 660,
#   '갖다': 661,
#   '참고': 662,
#   '더욱': 663,
#   '거기': 664,
#   '확실하다': 665,
#   '100': 666,
#   '가보다': 667,
#   '구': 668,
#   '불편하다': 669,
#   '걸리다': 670,
#   '면': 671,
#   '점점': 672,
#   '들어가다': 673,
#   '아빠': 674,
#   '수가': 675,
#   '역대': 676,
#   '평범하다': 677,
#   '편집': 678,
#   '완성': 679,
#   '거지': 680,
#   '단순하다': 681,
#   '잃다': 682,
#   '전형': 683,
#   '어이': 684,
#   '멜로': 685,
#   '듣다': 686,
#   '허무하다': 687,
#   '끼다': 688,
#   '흐르다': 689,
#   '상미': 690,
#   '때리다': 691,
#   '짧다': 692,
#   '술': 693,
#   '화이팅': 694,
#   '과': 695,
#   '초': 696,
#   '동안': 697,
#   '탄탄하다': 698,
#   '가지다': 699,
#   '드': 700,
#   '불륜': 701,
#   '걸다': 702,
#   '진행': 703,
#   '개그': 704,
#   '돋보이다': 705,
#   '엉망': 706,
#   '잠': 707,
#   '예상': 708,
#   '중반': 709,
#   '즐기다': 710,
#   '미화': 711,
#   'd': 712,
#   '지겹다': 713,
#   '사건': 714,
#   '그게': 715,
#   '소중하다': 716,
#   '키': 717,
#   '똑같다': 718,
#   '병맛': 719,
#   '몇': 720,
#   '설명': 721,
#   '과거': 722,
#   '프랑스': 723,
#   '찾아보다': 724,
#   '또한': 725,
#   '적당하다': 726,
#   '20': 727,
#   '중요하다': 728,
#   '꿀잼': 729,
#   '메다': 730,
#   '손': 731,
#   '훈훈하다': 732,
#   '무': 733,
#   '도저히': 734,
#   '노력': 735,
#   '흥미진진': 736,
#   '원래': 737,
#   '댓글': 738,
#   '그래픽': 739,
#   '티': 740,
#   '흥미': 741,
#   '죽음': 742,
#   '마르다': 743,
#   '리': 744,
#   '취향': 745,
#   '비추다': 746,
#   '갈다': 747,
#   '싸우다': 748,
#   '거리': 749,
#   '척': 750,
#   '무조건': 751,
#   '몸': 752,
#   '식상하다': 753,
#   '배': 754,
#   '자극': 755,
#   '뛰어나다': 756,
#   '화가': 757,
#   '울': 758,
#   '화보': 759,
#   '역겹다': 760,
#   '감상': 761,
#   '새끼': 762,
#   '한심하다': 763,
#   '관': 764,
#   '학교': 765,
#   '고': 766,
#   '자꾸': 767,
#   '닿다': 768,
#   '길다': 769,
#   '뭐라다': 770,
#   '아저씨': 771,
#   '예고편': 772,
#   '오히려': 773,
#   '액션영화': 774,
#   '바보': 775,
#   '심리': 776,
#   '결혼': 777,
#   '봣': 778,
#   '속편': 779,
#   '오': 780,
#   '헐다': 781,
#   '다루다': 782,
#   '터': 783,
#   '게임': 784,
#   '연기자': 785,
#   '법': 786,
#   '잘만': 787,
#   '90년': 788,
#   '보이': 789,
#   '마무리': 790,
#   '천재': 791,
#   '강하다': 792,
#   '관계': 793,
#   '미안하다': 794,
#   '참신하다': 795,
#   '나르다': 796,
#   'ㄷㄷ': 797,
#   '억지로': 798,
#   '표정': 799,
#   '귀신': 800,
#   '땐': 801,
#   '최근': 802,
#   '현재': 803,
#   '전설': 804,
#   '산': 805,
#   '상상': 806,
#   '불다': 807,
#   '여': 808,
#   '유치': 809,
#   '기억나다': 810,
#   '식': 811,
#   '전편': 812,
#   '짐': 813,
#   '촬영': 814,
#   '아무': 815,
#   '아쉬움': 816,
#   '대한민국': 817,
#   '젠': 818,
#   '총': 819,
#   '흘리다': 820,
#   '나서다': 821,
#   '빠져들다': 822,
#   '대작': 823,
#   '개다': 824,
#   '짓': 825,
#   '타임': 826,
#   '잊혀지다': 827,
#   '열': 828,
#   '회': 829,
#   '다가': 830,
#   '길': 831,
#   '그닥': 832,
#   '흠': 833,
#   '다니다': 834,
#   '묘사': 835,
#   '메세지': 836,
#   '존': 837,
#   '스타': 838,
#   '진지하다': 839,
#   '겁나다': 840,
#   '철학': 841,
#   '마': 842,
#   '동화': 843,
#   '프로그램': 844,
#   '프로': 845,
#   '그림': 846,
#   '드럽다': 847,
#   '조연': 848,
#   '돌아가다': 849,
#   '2시간': 850,
#   '여전하다': 851,
#   '씨': 852,
#   '쩔다': 853,
#   '사라지다': 854,
#   '전달': 855,
#   '역할': 856,
#   '실망하다': 857,
#   '끌다': 858,
#   '나중': 859,
#   '서로': 860,
#   '전작': 861,
#   '유머': 862,
#   '등장': 863,
#   '소녀': 864,
#   '경찰': 865,
#   '졸라': 866,
#   '먼저': 867,
#   '다행': 868,
#   'ㅇ': 869,
#   '마치': 870,
#   '멍청하다': 871,
#   '무비': 872,
#   '정': 873,
#   '노': 874,
#   '작다': 875,
#   '살인': 876,
#   '영원하다': 877,
#   '흔하다': 878,
#   '주의': 879,
#   '런가': 880,
#   '다만': 881,
#   '화': 882,
#   '특유': 883,
#   '살아가다': 884,
#   '망작': 885,
#   '잘생기다': 886,
#   '약하다': 887,
#   '80년': 888,
#   '통해': 889,
#   '행동': 890,
#   '환상': 891,
#   '햇': 892,
#   '부터': 893,
#   '겠다': 894,
#   '입': 895,
#   '인정': 896,
#   '지루': 897,
#   '바뀌다': 898,
#   '틀다': 899,
#   '저런': 900,
#   '바람': 901,
#   '노출': 902,
#   '관심': 903,
#   '미래': 904,
#   '덥다': 905,
#   '예산': 906,
#   '청춘': 907,
#   '군대': 908,
#   '리메이크': 909,
#   '착하다': 910,
#   '묻다': 911,
#   '황당하다': 912,
#   'x': 913,
#   '깊이': 914,
#   '빌리다': 915,
#   '가능하다': 916,
#   '쏘다': 917,
#   '안나': 918,
#   '모': 919,
#   'ㅅㅂ': 920,
#   '반개': 921,
#   '깔다': 922,
#   '제작비': 923,
#   '위대하다': 924,
#   '영웅': 925,
#   '효과': 926,
#   '졸리다': 927,
#   '용도': 928,
#   '손발': 929,
#   '외': 930,
#   '생애': 931,
#   '얼': 932,
#   '케이블': 933,
#   '평생': 934,
#   '시도': 935,
#   '과정': 936,
#   '유명하다': 937,
#   '지나치다': 938,
#   '인하다': 939,
#   '채널': 940,
#   '범인': 941,
#   '희망': 942,
#   '강': 943,
#   '단': 944,
#   '반': 945,
#   '얻다': 946,
#   '형님': 947,
#   '젊다': 948,
#   '능력': 949,
#   '상상력': 950,
#   '가끔': 951,
#   '스케일': 952,
#   '미소': 953,
#   '태어나다': 954,
#   '신기하다': 955,
#   '카메라': 956,
#   '결론': 957,
#   '네': 958,
#   '시': 959,
#   '다소': 960,
#   'good': 961,
#   '설레다': 962,
#   '독립영화': 963,
#   '낚': 964,
#   '늙다': 965,
#   '광고': 966,
#   '대안': 967,
#   '던지다': 968,
#   '온': 969,
#   '대충': 970,
#   'dvd': 971,
#   '생': 972,
#   '자막': 973,
#   '잘못': 974,
#   '메시지': 975,
#   '체': 976,
#   '한계': 977,
#   '고민': 978,
#   '슬픔': 979,
#   '여성': 980,
#   '고맙다': 981,
#   '부족': 982,
#   '빠르다': 983,
#   '참다': 984,
#   '안다': 985,
#   '고생': 986,
#   '변하다': 987,
#   '다시다': 988,
#   '찌다': 989,
#   '원하다': 990,
#   '차': 991,
#   '울리다': 992,
#   '이면': 993,
#   '커플': 994,
#   '리얼': 995,
#   '밤': 996,
#   '졸다': 997,
#   '동생': 998,
#   '방': 999,
#   '산만하다': 1000,
#   ...},
#  44611)

# %%
# Sequence 만들기 / Padding하기 - train, test 모두 
training_sequences  = tokenizer.texts_to_sequences(training_sentences)
training_padded = pad_sequences(training_sequences, maxlen=max_length, 
                                padding=padding_type, truncating=truct_type)


testing_sequences  = tokenizer.texts_to_sequences(testing_sentences)
testing_padded = pad_sequences(testing_sequences, maxlen=max_length, 
                                padding=padding_type, truncating=truct_type)

# %% [markdown]
# ## Word2Vec weight 만들기

# %%
ko_model

# %%
import numpy as np

vocab_size = len(tokenizer.index_word) + 1
embedding_dim = 200

embedding_matrix = np.zeros((vocab_size, embedding_dim))

# tokenizer에 있는 단어 사전을 순회하면서 word2vec의 200차원 vector를 가져오기
for word, idx in tokenizer.word_index.items():
    embedding_vector = ko_model[word] if word in ko_model else None
    if embedding_vector is not None:
        embedding_matrix[idx] = embedding_vector
        
embedding_matrix.shape
# Out:
# C:\Users\leeso\anaconda\envs\crawl\lib\site-packages\ipykernel_launcher.py:10: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\leeso\anaconda\envs\crawl\lib\site-packages\ipykernel_launcher.py:10: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   # Remove the CWD from sys.path while we load stuff.
# (44612, 200)

# %%
word_index['최고']
# Out:
# 23

# %%
ko_model['최고']
# Out:
# C:\Users\leeso\anaconda\envs\crawl\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# array([-0.8588482 ,  0.92817163,  0.02203734,  1.3697246 , -0.4709991 ,
#        -1.5010548 , -0.49414608,  0.4925356 , -0.23244537, -0.04845205,
#         0.09304108, -0.11300896,  0.5571053 , -0.11795222,  0.49380097,
#        -0.5556328 ,  0.11953602, -0.18062858, -1.2581393 , -0.81152546,
#         0.42466506,  0.8579601 ,  0.19897878, -0.81691873,  0.8666564 ,
#        -1.0465446 , -0.4982905 ,  0.2539313 , -0.09490417, -0.93356013,
#        -1.643275  ,  0.3243457 ,  1.2613564 ,  1.1039764 , -0.21867326,
#        -0.55674183,  0.90235335, -1.1716101 ,  0.77494115, -0.5213071 ,
#        -0.21292363, -0.302229  , -0.80103284, -0.12620486, -1.195164  ,
#        -0.22341141,  0.38163522,  0.00649113,  0.2602783 ,  0.02779087,
#         0.95976293, -0.24270368, -0.39551368,  0.12866431, -0.59832066,
#         0.12882997, -0.12808815,  0.87104553,  0.00889622, -0.32881373,
#         0.03664391,  0.78057766,  0.28789434,  2.0120773 ,  0.0571333 ,
#         1.2447547 , -0.7004512 , -0.26596418, -0.51164573,  0.31788218,
#         0.6809982 , -1.1155411 , -0.09103616, -0.42794025,  0.17228958,
#         0.1538465 , -0.20262402, -0.09419158, -0.04925876,  0.75968885,
#        -1.0809007 ,  1.3401028 ,  0.39595917,  1.0748714 ,  0.6797664 ,
#        -0.8501222 ,  0.63369566,  0.2163268 , -0.5303719 , -0.5312083 ,
#        -0.49126494, -0.85349196,  0.13101861, -0.38891166, -0.02576141,
#        -1.8536321 ,  0.8057069 , -0.37110516, -0.37010357, -0.13792415,
#         0.0872428 , -0.07057373, -0.14079009, -0.0882552 , -1.5414639 ,
#         0.08164613,  0.57140744,  1.055643  ,  0.32159892, -0.2730514 ,
#        -0.9037401 , -0.34642386,  0.76921463, -0.5925871 ,  1.2521826 ,
#         0.24357602,  0.33998114, -0.69548696,  1.3901985 , -0.35703877,
#         0.31514573,  0.11629552, -1.3958768 ,  0.5845511 ,  0.20291877,
#         1.2148008 ,  0.18424594, -0.46534598, -0.9087082 ,  0.44782987,
#         0.82926345, -1.2176589 , -0.80595845,  2.1184216 ,  0.0706705 ,
#         0.35223395,  0.16623954,  0.25785488, -1.0124867 ,  1.343551  ,
#         0.5700985 , -0.25236714,  1.538589  , -0.20186408,  0.15322793,
#        -0.09332677, -0.37294033,  1.1418074 , -1.0254471 , -0.36533278,
#        -0.01202002, -0.41665232, -0.5981209 , -0.63845223, -0.3621869 ,
#         1.8482066 ,  0.69762963, -1.080145  , -1.0401994 ,  0.3541005 ,
#        -0.05727062, -0.70051324, -1.022972  ,  0.14561783, -0.17227724,
#        -0.6672173 , -0.15351965, -0.12619644, -0.14825901,  0.90405506,
#        -1.1766773 ,  0.03866967, -0.78964615, -0.11472937,  0.88905376,
#        -0.57539517,  0.17546913,  0.35434532, -0.452573  ,  0.01550079,
#        -0.8241312 ,  1.1627038 , -0.392777  ,  0.08164232,  0.6030082 ,
#        -0.7795996 ,  2.221553  ,  0.05683346, -0.76498526,  0.74309766,
#         1.2266463 , -0.02246751,  1.2970965 , -0.7560647 ,  1.0034068 ,
#        -0.45882082, -0.09042309, -0.01749961, -1.0427607 ,  0.6032626 ],
#       dtype=float32)

# %%
embedding_matrix[16]
# Out:
# array([-0.65613872, -0.1878451 , -2.28804922, -0.60850179, -0.20944199,
#        -0.73954386,  0.45581877,  0.21562536, -2.23071456,  0.82642019,
#        -2.05929804, -1.13468277,  0.03894617,  0.85293633, -0.44432551,
#        -1.03018618, -0.01358046,  0.33014327, -0.36980888,  0.31315118,
#        -0.07146841, -0.06222904,  0.22098194,  1.10881281,  0.55845213,
#        -1.3358885 , -0.57032239,  0.09883324,  0.27421305,  0.37706429,
#        -0.09907344,  0.66710508, -0.56833786,  0.21092594,  0.28369167,
#        -1.00925922,  0.43218195,  1.21249568,  1.07392037,  1.28291428,
#        -1.90316272,  1.17173433, -0.47084916,  0.65514529, -0.10202166,
#        -1.52839541, -0.12795947,  1.60741544,  1.15357125, -1.92110121,
#        -0.47887081,  0.40243226, -1.28478301, -0.75054759,  0.51739645,
#        -0.70001084, -2.03475833, -0.02315634, -1.20234525, -0.87681413,
#        -0.80264157, -1.0190345 ,  0.43861088,  0.06535848, -0.78121197,
#         0.28091148,  0.85786098, -0.21858822, -1.00957274, -0.46521601,
#        -0.25901803, -0.65014952,  0.3342526 ,  0.38050711,  1.13121259,
#         0.87498444,  0.40052032, -0.11301954,  0.21142618,  0.3045285 ,
#        -0.24147765,  0.05909223,  0.52685618, -0.4819867 , -1.56623566,
#         0.716537  , -1.17143571,  1.24371123, -1.14902806, -0.33624402,
#         0.43546304,  1.60761011, -0.36909536,  0.48993152, -0.80113232,
#         0.17063208, -0.65727037, -0.62282342,  0.01929487,  1.8613888 ,
#         0.15052944, -0.22955956,  0.44660592, -0.77585083,  0.45030057,
#        -0.1025486 ,  0.56964278, -0.10599346,  0.00955601, -0.42616305,
#         0.66644311, -0.05597176,  0.95347095, -0.96630168, -0.5728963 ,
#        -0.93120575,  1.00355673,  0.7544722 , -0.39509046, -0.79964608,
#         0.92124426, -0.33325785, -1.30690634,  1.46195316, -0.12628473,
#         1.41267014,  0.74522263,  0.46554235,  0.25859648,  1.56066203,
#        -1.72575843,  0.59138727,  1.28134906, -0.72198772,  0.99563736,
#        -0.145023  ,  0.08948908, -1.14637995, -1.0508064 ,  1.11279047,
#         0.3289867 ,  1.12986887,  1.31431639, -0.43001032,  1.86617434,
#        -0.83285064,  0.36152443, -0.18050967, -0.54131317,  1.28088045,
#         0.02621703, -1.49857211,  0.72746897, -0.69925582, -0.69947827,
#        -0.64881504, -0.68940908, -0.04584072,  0.55091447, -0.06357186,
#        -1.23696244, -0.67206204, -0.47228324,  0.74641776, -0.25864443,
#         1.63122082,  0.85175663,  0.74608928,  0.44476748, -0.42925432,
#         1.74521947, -0.2528165 ,  1.05846167, -0.62123787, -1.95495653,
#         1.09468031,  0.4088915 ,  0.03553591, -2.06684113,  0.29022229,
#        -0.90919727, -1.15995717,  1.12759948, -0.07642239, -1.60873079,
#         0.59230995,  1.27595305,  1.60375237, -0.75642645,  1.41847563,
#        -0.46087009,  0.80623174,  1.32337523, -0.36153418,  0.63374448,
#         0.28176752,  3.20045137,  0.69714206, -0.78915495, -0.65367573])

# %% [markdown]
# ## 모델링

# %%
# 모델링  - L2 추가 
embedding_dim = 200
filter_sizes = (3, 4, 5)
num_filters = 100
dropout = 0.5
hidden_dims = 100

conv_blocks =[]
input_shape = (30)
model_input = tf.keras.layers.Input(shape=input_shape)
z = model_input
for sz in filter_sizes:
    embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length,
                                         weights = [embedding_matrix], trainable = False)(z)
    conv = tf.keras.layers.Conv1D(filters=num_filters,
                         kernel_size=sz,
                         padding="valid",
                         activation="relu",
                         strides=1)(embedding)
    conv = tf.keras.layers.GlobalAveragePooling1D()(conv)
    conv = tf.keras.layers.Flatten()(conv)
    conv_blocks.append(conv)
z = tf.keras.layers.Concatenate()(conv_blocks) if len(conv_blocks) > 1 else conv_blocks[0]

z = tf.keras.layers.Dense(hidden_dims, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(0.003), bias_regularizer=tf.keras.regularizers.l2(0.003))(z)
z = tf.keras.layers.Dropout(dropout)(z)
model_output = tf.keras.layers.Dense(1, activation="sigmoid")(z)
model = tf.keras.Model(model_input, model_output)

# %%
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 30)]         0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 30, 200)      8922400     input_1[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 30, 200)      8922400     input_1[0][0]
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 30, 200)      8922400     input_1[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 28, 100)      60100       embedding[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 27, 100)      80100       embedding_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 26, 100)      100100      embedding_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 100)          0           conv1d[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_1 (Glo (None, 100)          0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_2 (Glo (None, 100)          0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 100)          0           global_average_pooling1d[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 100)          0           global_average_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 100)          0           global_average_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 300)          0           flatten[0][0]
#                                                                  flatten_1[0][0]
#                                                                  flatten_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 100)          30100       concatenate[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 100)          0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            101         dropout[0][0]
# ==================================================================================================
# Total params: 27,037,701
# Trainable params: 270,501
# Non-trainable params: 26,767,200
# __________________________________________________________________________________________________

# %%
def plot_graphs(history, string, name='model'):
    plt.plot(history.history[string])
    plt.plot(history.history['val_' + string])
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.title(name)
    plt.legend([string, 'val_' + string])

    fig = plt.gcf()
    ##저장될 폴더생성
    result_dir = './result_file'
    if not os.path.exists(result_dir):
        os.makedirs(result_dir)
    fig.savefig(result_dir+'/{}.png'.format(name), dpi = fig.dpi)
    print('<{}.png> result_file폴더에 결과 그래프 저장 완료'.format(name))
    plt.show()

# %%
batch_size = 50
num_epochs = 10
min_word_count = 1
context = 10

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

checkpoint_dir = './ckpt2'
if not os.path.exists(checkpoint_dir):
  os.makedirs(checkpoint_dir)
callbacks = [
  keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=0),   
  keras.callbacks.ModelCheckpoint(
      filepath=checkpoint_dir + '/ckpt2-loss={loss:.3f}')
  ]

history = model.fit(training_padded, training_labels, epochs=10, callbacks=callbacks, batch_size = batch_size, validation_data=(testing_padded, testing_labels))
accuracy_graph = plot_graphs(history, 'accuracy',name='model2_accuracy')
loss_graph= plot_graphs(history, 'loss',name='model2_loss')
